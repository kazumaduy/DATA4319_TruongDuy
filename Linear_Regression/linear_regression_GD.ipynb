# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data

data = pd.read_csv('data.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
cmap = sb.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sb.set(style="darkgrid")
sb.scatterplot(X, Y, color= sb.xkcd_rgb["dark violet"])
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.4796491688889395 0.10148121494753726

# %%
Y_pred = m*X + c
sb.set(style='darkgrid')
sb.scatterplot(X, Y, color= sb.xkcd_rgb["dark violet"]) 
sb.lineplot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color = sb.xkcd_rgb["cyan"])  # regression line
plt.show()
